# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('customer_clustering_data.csv')

# %%
data
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0              6.454695                7.268467
# 1              5.766484                6.431171
# 2              5.477369                2.087178
# 3              3.198239                7.739520
# 4              2.898585                6.759572
# ..                  ...                     ...
# 995            3.787372                5.067560
# 996            1.573018                9.956804
# 997            3.215781                5.921743
# 998            3.725611                1.692713
# 999            7.722879                7.193942
#
# [1000 rows x 2 columns]

# %%
X = data[['Annual Income (k$)', 'Spending Score (1-100)']].values
X
# Out:
# array([[6.45469538, 7.26846705],
#        [5.76648413, 6.43117072],
#        [5.47736921, 2.08717777],
#        ...,
#        [3.2157805 , 5.92174278],
#        [3.72561053, 1.69271273],
#        [7.72287923, 7.1939424 ]])

# %%
x_new = StandardScaler().fit_transform(X)
x_new
# Out:
# array([[ 0.76643878,  0.40322961],
#        [ 0.45838986,  0.13920793],
#        [ 0.32897968, -1.23056794],
#        ...,
#        [-0.68332573, -0.02142817],
#        [-0.45512168, -1.3549532 ],
#        [ 1.33408813,  0.37973002]])

# %%
dbscan = DBSCAN(eps=0.2, min_samples=8)
y_pred =dbscan.fit_predict(x_new)

# %%
plt.scatter(x_new[:,0], x_new[:,1], c=y_pred)
plt.colorbar(label='Cluster Label')
